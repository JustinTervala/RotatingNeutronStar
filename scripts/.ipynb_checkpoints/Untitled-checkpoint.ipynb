# %%
import timers
import matplotlib.pyplot as plt
import numpy as np

# %%
spin = timers.main()
# Out:
# Execution Time in Milliseconds
# spin():
#    Func     Avg      Med      Min      Max      Std   Calls  Percent
#     total  136.46   121.06   31.01    416.36   63.53  1200   100.0
#       vep   3.39     4.23     0.74    202.45    2.87  16900  34.961
#     coeff   1.95     0.98     0.31    53.32     1.63  16900  20.124
#    metric   1.52     0.75     0.23    16.98     1.4   16900  15.651
#       rad   1.21     0.59     0.09    85.83     1.46  16900  12.505
#     alpha   1.01     0.49     0.05    30.76     1.25  16900  10.459
#       ang   0.34     0.15     0.05    32.87     0.81  16900  3.481
# mass_radius():
#   min: 1.055644
#   max: 12.149981
#   avg: 3.34448562083
#   std: 1.73629812841

# %%
plt.plot(np.divide(spin['coeff'], 1.e6))
plt.show()
